# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

df=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

X=df.iloc[:,:-1]
X_test=df_test.iloc[:,:]
Y=df.iloc[:,-1]

# %%
df.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# ...

# %%
sns.countplot(df.Response)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Response', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(df.City_Code)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='City_Code', ylabel='count'>

# %%
f=plt.figure(figsize=(15,8))

f.add_subplot(1,2,1)
sns.distplot(df.Upper_Age)

f.add_subplot(1,2,2)
sns.boxplot(df.Upper_Age)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Upper_Age'>

# %%
f=plt.figure(figsize=(15,8))

f.add_subplot(1,2,1)
sns.distplot(df.Lower_Age)

f.add_subplot(1,2,2)
sns.boxplot(df.Lower_Age)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Lower_Age'>

# %% [markdown]
# From here we can see that Upper Age and Lower age have no outliers but they does not seem to be normalised.
# Also they are correlated.
# Lets create a new variable : age_differnce = Upper_Age-Lower_Age

# %%
df['Age_Diff']=df.Upper_Age-df.Lower_Age

# %%
f=plt.figure(figsize=(15,8))

f.add_subplot(1,2,1)
sns.distplot(df.Age_Diff)

f.add_subplot(1,2,2)
sns.boxplot(df.Age_Diff)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age_Diff'>

# %%
f=plt.figure(figsize=(20,5))

f.add_subplot(1,3,1)
sns.countplot(df.Accomodation_Type,color='Red')

f.add_subplot(1,3,2)
sns.countplot(df.Reco_Insurance_Type,color='Green')

f.add_subplot(1,3,3)
sns.countplot(df.Is_Spouse,color='Blue')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# 1. Accomadation seem to be equally ditributed for both Rented and Owned.
# 2. Prepole with Individual reco_insurence_type are more then Joint.
# 3. People who doesnot have spouse are greater.

# %%
f=plt.figure(figsize=(15,8))

f.add_subplot(1,2,1)
sns.distplot(df.Reco_Policy_Premium)

f.add_subplot(1,2,2)
sns.boxplot(df.Reco_Policy_Premium)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Reco_Policy_Premium'>

# %% [markdown]
# Reco_Policy_Premium : it is full of outliers

# %%
f=plt.figure(figsize=(15,8))

f.add_subplot(1,2,1)
sns.distplot(df.Region_Code)

f.add_subplot(1,2,2)
sns.boxplot(df.Region_Code)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region_Code'>

# %%
f.add_subplot(1,2,1)
sns.countplot(df.Region_Code)
# Out:
# <ipython-input-29-588f080a3f09>:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   f.add_subplot(1,2,1)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region_Code', ylabel='count'>

# %%
Health Indicator	Holding_Policy_Duration	Holding_Policy_Type	Reco_Policy_Cat

# %%
f=plt.figure(figsize=(20,5))

f.add_subplot(1,2,1)
sns.countplot(df['Health Indicator'],color='Red')

f.add_subplot(1,2,2)
sns.countplot(df.Holding_Policy_Duration,color='Blue')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Holding_Policy_Duration', ylabel='count'>

# %%
df.corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
# #T_9d75d035_79a7_11eb_970f_907841bca957row0_col0,#T_9d75d035_79a7_11eb_970f_907841bca957row1_col1,#T_9d75d035_79a7_11eb_970f_907841bca957row2_col2,#T_9d75d035_79a7_11eb_970f_907841bca957row3_col3,#T_9d75d035_79a7_11eb_970f_907841bca957row4_col4,#T_9d75d035_79a7_11eb_970f_907841bca957row5_col5,#T_9d75d035_79a7_11eb_970f_907841bca957row6_col6,#T_9d75d035_79a7_11eb_970f_907841bca957row7_col7,#T_9d75d035_79a7_11eb_970f_907841bca957row8_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_9d75d035_79a7_11eb_970f_907841bca957row0_col1,#T_9d75d035_79a7_11eb_970f_907841bca957row0_col5,#T_9d75d035_79a7_11eb_970f_907841bca957row7_col1,#T_9d75d035_79a7_11eb_970f_907841bca957row8_col1{
#             background-color:  #f6eff7;
#             color:  #000000;
# ...

# %% [markdown]
# ##  Doing the crosstab analysis of Categorical Variable

# %%
df.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
pd.crosstab(df['Reco_Policy_Cat'],df.Response)
# Out:
# Response            0     1
# Reco_Policy_Cat
# 1                1959     8
# 2                1663   254
# 3                 854   205
# 4                 940    75
# 5                 714   293
# 6                 704   147
# 7                 679   155
# 8                 567   209
# 9                 658   131
# 10                634   136
# 11                651   130
# 12               1485   683
# 13               1316   368
# 14               1317   425
# 15                863   752
# 16               3171   913
# 17               2635  1121
# 18               4328  1225
# 19               2681  1027
# 20               2367   810
# 21               4053   974
# 22               4434  2168

# %%
pd.crosstab(df['Reco_Policy_Cat'],df.Response,normalize='index')
# Out:
# Response                0         1
# Reco_Policy_Cat
# 1                0.995933  0.004067
# 2                0.867501  0.132499
# 3                0.806421  0.193579
# 4                0.926108  0.073892
# 5                0.709037  0.290963
# 6                0.827262  0.172738
# 7                0.814149  0.185851
# 8                0.730670  0.269330
# 9                0.833967  0.166033
# 10               0.823377  0.176623
# 11               0.833547  0.166453
# 12               0.684963  0.315037
# 13               0.781473  0.218527
# 14               0.756028  0.243972
# 15               0.534365  0.465635
# 16               0.776445  0.223555
# 17               0.701544  0.298456
# 18               0.779399  0.220601
# 19               0.723031  0.276969
# 20               0.745042  0.254958
# 21               0.806246  0.193754
# 22               0.671615  0.328385

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50882 entries, 0 to 50881
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       50882 non-null  int64
#  1   City_Code                50882 non-null  object
#  2   Region_Code              50882 non-null  int64
#  3   Accomodation_Type        50882 non-null  object
#  4   Reco_Insurance_Type      50882 non-null  object
#  5   Upper_Age                50882 non-null  int64
#  6   Lower_Age                50882 non-null  int64
#  7   Is_Spouse                50882 non-null  object
#  8   Health Indicator         39191 non-null  object
#  9   Holding_Policy_Duration  30631 non-null  object
#  10  Holding_Policy_Type      30631 non-null  float64
#  11  Reco_Policy_Cat          50882 non-null  int64
#  12  Reco_Policy_Premium      50882 non-null  float64
#  13  Response                 50882 non-null  int64
# ...

# %% [markdown]
# ## Lets do some for continuous variables

# %%
sns.violinplot(x='Response',y='Region_Code',data=df)
# Out:
# <AxesSubplot:xlabel='Response', ylabel='Region_Code'>

# %%
sns.violinplot(x='Response',y='Upper_Age',data=df)
# Out:
# <AxesSubplot:xlabel='Response', ylabel='Upper_Age'>

# %%
sns.violinplot(x='Response',y='Lower_Age',data=df)
# Out:
# <AxesSubplot:xlabel='Response', ylabel='Lower_Age'>

# %%
sns.violinplot(x='Response',y='Reco_Policy_Premium',data=df)
# Out:
# <AxesSubplot:xlabel='Response', ylabel='Reco_Policy_Premium'>

# %%
sns.violinplot(x='Response',y='Age_Diff',data=df)
# Out:
# <AxesSubplot:xlabel='Response', ylabel='Age_Diff'>

# %%
len([i for i in df.Response if i==0])
# Out:
# 38673

# %%
len([i for i in df.Response if i==1])
# Out:
# 12209
